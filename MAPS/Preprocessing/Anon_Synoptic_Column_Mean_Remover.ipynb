# %%
import numpy as np
import math
import xarray as xr
import dask

# %%
T_Diurnal_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Composite/T_amazon_point.npy")
T_Diurnal_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Composite/T_ocean_point.npy")
T_Synoptic_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Synoptic_Composite/T_amazon_point.npy")
T_Synoptic_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Synoptic_Composite/T_ocean_point.npy")
T_Two_Week_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Two_Week_Composite/T_amazon_point.npy")
T_Two_Week_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Two_Week_Composite/T_ocean_point.npy")
T_Diurnal_Avg_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Avg/T_amazon_region.npy")
T_Diurnal_Avg_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Avg/T_ocean_region.npy")
T_Diurnal_Int_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Daily_Interval/T_amazon_region.npy")
T_Diurnal_Int_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Daily_Interval/T_ocean_region.npy")

Q_Diurnal_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Composite/Q_amazon_point.npy")
Q_Diurnal_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Composite/Q_ocean_point.npy")
Q_Synoptic_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Synoptic_Composite/Q_amazon_point.npy")
Q_Synoptic_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Synoptic_Composite/Q_ocean_point.npy")
Q_Two_Week_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Two_Week_Composite/Q_amazon_point.npy")
Q_Two_Week_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Two_Week_Composite/Q_ocean_point.npy")
Q_Diurnal_Avg_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Avg/Q_amazon_region.npy")
Q_Diurnal_Avg_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Avg/Q_ocean_region.npy")
Q_Diurnal_Int_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Daily_Interval/Q_amazon_region.npy")
Q_Diurnal_Int_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Daily_Interval/Q_ocean_region.npy")

E_Diurnal_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Composite/E_amazon_point.npy")
E_Diurnal_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Composite/E_ocean_point.npy")
E_Synoptic_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Synoptic_Composite/E_amazon_point.npy")
E_Synoptic_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Synoptic_Composite/E_ocean_point.npy")
E_Two_Week_Comp_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Two_Week_Composite/E_amazon_point.npy")
E_Two_Week_Comp_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Two_Week_Composite/E_ocean_point.npy")
E_Diurnal_Avg_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Avg/E_amazon_region.npy")
E_Diurnal_Avg_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Diurnal_Avg/E_ocean_region.npy")
E_Diurnal_Int_Amazon = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Daily_Interval/E_amazon_region.npy")
E_Diurnal_Int_Ocean = np.load("/fast/gmooers/Preprocessed_Data/Synoptic_Test_Data/Daily_Interval/E_ocean_region.npy")

T_Max = np.load("/fast/gmooers/Preprocessed_Data/T_Variable/Space_Time_Max_Scalar.npy")
T_Min = np.load("/fast/gmooers/Preprocessed_Data/T_Variable/Space_Time_Min_Scalar.npy")
Q_Max = np.load("/fast/gmooers/Preprocessed_Data/Q_Variable/Space_Time_Max_Scalar.npy")
Q_Min = np.load("/fast/gmooers/Preprocessed_Data/Q_Variable/Space_Time_Min_Scalar.npy")
E_Max = np.load("/fast/gmooers/Preprocessed_Data/Enthalpy_Variable/Space_Time_Max_Scalar.npy")
E_Min = np.load("/fast/gmooers/Preprocessed_Data/Enthalpy_Variable/Space_Time_Min_Scalar.npy")

# %%
T_Diurnal_Comp_Amazon_Unscaled = np.interp(T_Diurnal_Comp_Amazon, (0, 1), (T_Min, T_Max))
T_Diurnal_Comp_Ocean_Unscaled = np.interp(T_Diurnal_Comp_Ocean, (0, 1), (T_Min, T_Max))
T_Synoptic_Comp_Amazon_Unscaled = np.interp(T_Synoptic_Comp_Amazon, (0, 1), (T_Min, T_Max))
T_Synoptic_Comp_Ocean_Unscaled = np.interp(T_Synoptic_Comp_Ocean, (0, 1), (T_Min, T_Max))
T_Two_Week_Comp_Amazon_Unscaled = np.interp(T_Two_Week_Comp_Amazon, (0, 1), (T_Min, T_Max))
T_Two_Week_Comp_Ocean_Unscaled = np.interp(T_Two_Week_Comp_Ocean, (0, 1), (T_Min, T_Max))
T_Diurnal_Avg_Amazon_Unscaled = np.interp(T_Diurnal_Avg_Amazon, (0, 1), (T_Min, T_Max))
T_Diurnal_Avg_Ocean_Unscaled = np.interp(T_Diurnal_Avg_Ocean, (0, 1), (T_Min, T_Max))
T_Diurnal_Int_Amazon_Unscaled = np.interp(T_Diurnal_Int_Amazon, (0, 1), (T_Min, T_Max))
T_Diurnal_Int_Ocean_Unscaled = np.interp(T_Diurnal_Int_Ocean, (0, 1), (T_Min, T_Max))

Q_Diurnal_Comp_Amazon_Unscaled = np.interp(Q_Diurnal_Comp_Amazon, (0, 1), (Q_Min, Q_Max))
Q_Diurnal_Comp_Ocean_Unscaled = np.interp(Q_Diurnal_Comp_Ocean, (0, 1), (Q_Min, Q_Max))
Q_Synoptic_Comp_Amazon_Unscaled = np.interp(Q_Synoptic_Comp_Amazon, (0, 1), (Q_Min, Q_Max))
Q_Synoptic_Comp_Ocean_Unscaled = np.interp(Q_Synoptic_Comp_Ocean, (0, 1), (Q_Min, Q_Max))
Q_Two_Week_Comp_Amazon_Unscaled = np.interp(Q_Two_Week_Comp_Amazon, (0, 1), (Q_Min, Q_Max))
Q_Two_Week_Comp_Ocean_Unscaled = np.interp(Q_Two_Week_Comp_Ocean, (0, 1), (Q_Min, Q_Max))
Q_Diurnal_Avg_Amazon_Unscaled = np.interp(Q_Diurnal_Avg_Amazon, (0, 1), (Q_Min, Q_Max))
Q_Diurnal_Avg_Ocean_Unscaled = np.interp(Q_Diurnal_Avg_Ocean, (0, 1), (Q_Min, Q_Max))
Q_Diurnal_Int_Amazon_Unscaled = np.interp(Q_Diurnal_Int_Amazon, (0, 1), (Q_Min, Q_Max))
Q_Diurnal_Int_Ocean_Unscaled = np.interp(Q_Diurnal_Int_Ocean, (0, 1), (Q_Min, Q_Max))

E_Diurnal_Comp_Amazon_Unscaled = np.interp(E_Diurnal_Comp_Amazon, (0, 1), (E_Min, E_Max))
E_Diurnal_Comp_Ocean_Unscaled = np.interp(E_Diurnal_Comp_Ocean, (0, 1), (E_Min, E_Max))
E_Synoptic_Comp_Amazon_Unscaled = np.interp(E_Synoptic_Comp_Amazon, (0, 1), (E_Min, E_Max))
E_Synoptic_Comp_Ocean_Unscaled = np.interp(E_Synoptic_Comp_Ocean, (0, 1), (E_Min, E_Max))
E_Two_Week_Comp_Amazon_Unscaled = np.interp(E_Two_Week_Comp_Amazon, (0, 1), (E_Min, E_Max))
E_Two_Week_Comp_Ocean_Unscaled = np.interp(E_Two_Week_Comp_Ocean, (0, 1), (E_Min, E_Max))
E_Diurnal_Avg_Amazon_Unscaled = np.interp(E_Diurnal_Avg_Amazon, (0, 1), (E_Min, E_Max))
E_Diurnal_Avg_Ocean_Unscaled = np.interp(E_Diurnal_Avg_Ocean, (0, 1), (E_Min, E_Max))
E_Diurnal_Int_Amazon_Unscaled = np.interp(E_Diurnal_Int_Amazon, (0, 1), (E_Min, E_Max))
E_Diurnal_Int_Ocean_Unscaled = np.interp(E_Diurnal_Int_Ocean, (0, 1), (E_Min, E_Max))

# %%
T_Diurnal_Comp_Amazon_Anon = np.empty(T_Diurnal_Comp_Amazon_Unscaled.shape)
T_Diurnal_Comp_Ocean_Anon = np.empty(T_Diurnal_Comp_Ocean_Unscaled.shape)
T_Synoptic_Comp_Amazon_Anon = np.empty(T_Synoptic_Comp_Amazon_Unscaled.shape)
T_Synoptic_Comp_Ocean_Anon = np.empty(T_Synoptic_Comp_Ocean_Unscaled.shape)
T_Two_Week_Comp_Amazon_Anon = np.empty(T_Two_Week_Comp_Amazon_Unscaled.shape)
T_Two_Week_Comp_Ocean_Anon = np.empty(T_Two_Week_Comp_Ocean_Unscaled.shape)
T_Diurnal_Avg_Amazon_Anon = np.empty(T_Diurnal_Avg_Amazon_Unscaled.shape)
T_Diurnal_Avg_Ocean_Anon = np.empty(T_Diurnal_Avg_Ocean_Unscaled.shape)
T_Diurnal_Int_Amazon_Anon = np.empty(T_Diurnal_Int_Amazon_Unscaled.shape)
T_Diurnal_Int_Ocean_Anon = np.empty(T_Diurnal_Int_Ocean_Unscaled.shape)

Q_Diurnal_Comp_Amazon_Anon = np.empty(Q_Diurnal_Comp_Amazon_Unscaled.shape)
Q_Diurnal_Comp_Ocean_Anon = np.empty(Q_Diurnal_Comp_Ocean_Unscaled.shape)
Q_Synoptic_Comp_Amazon_Anon = np.empty(Q_Synoptic_Comp_Amazon_Unscaled.shape)
Q_Synoptic_Comp_Ocean_Anon = np.empty(Q_Synoptic_Comp_Ocean_Unscaled.shape)
Q_Two_Week_Comp_Amazon_Anon = np.empty(Q_Two_Week_Comp_Amazon_Unscaled.shape)
Q_Two_Week_Comp_Ocean_Anon = np.empty(Q_Two_Week_Comp_Ocean_Unscaled.shape)
Q_Diurnal_Avg_Amazon_Anon = np.empty(Q_Diurnal_Avg_Amazon_Unscaled.shape)
Q_Diurnal_Avg_Ocean_Anon = np.empty(Q_Diurnal_Avg_Ocean_Unscaled.shape)
Q_Diurnal_Int_Amazon_Anon = np.empty(Q_Diurnal_Int_Amazon_Unscaled.shape)
Q_Diurnal_Int_Ocean_Anon = np.empty(Q_Diurnal_Int_Ocean_Unscaled.shape)

E_Diurnal_Comp_Amazon_Anon = np.empty(E_Diurnal_Comp_Amazon_Unscaled.shape)
E_Diurnal_Comp_Ocean_Anon = np.empty(E_Diurnal_Comp_Ocean_Unscaled.shape)
E_Synoptic_Comp_Amazon_Anon = np.empty(E_Synoptic_Comp_Amazon_Unscaled.shape)
E_Synoptic_Comp_Ocean_Anon = np.empty(E_Synoptic_Comp_Ocean_Unscaled.shape)
E_Two_Week_Comp_Amazon_Anon = np.empty(E_Two_Week_Comp_Amazon_Unscaled.shape)
E_Two_Week_Comp_Ocean_Anon = np.empty(E_Two_Week_Comp_Ocean_Unscaled.shape)
E_Diurnal_Avg_Amazon_Anon = np.empty(E_Diurnal_Avg_Amazon_Unscaled.shape)
E_Diurnal_Avg_Ocean_Anon = np.empty(E_Diurnal_Avg_Ocean_Unscaled.shape)
E_Diurnal_Int_Amazon_Anon = np.empty(E_Diurnal_Int_Amazon_Unscaled.shape)
E_Diurnal_Int_Ocean_Anon = np.empty(E_Diurnal_Int_Ocean_Unscaled.shape)

# %%
T_Diurnal_Comp_Amazon_Normalizer = np.empty(np.squeeze(T_Diurnal_Comp_Amazon_Unscaled[:,:,0]).shape)
T_Diurnal_Comp_Ocean_Normalizer = np.empty(np.squeeze(T_Diurnal_Comp_Ocean_Unscaled[:,:,0]).shape)
T_Synoptic_Comp_Amazon_Normalizer = np.empty(np.squeeze(T_Synoptic_Comp_Amazon_Unscaled[:,:,0]).shape)
T_Synoptic_Comp_Ocean_Normalizer = np.empty(np.squeeze(T_Synoptic_Comp_Ocean_Unscaled[:,:,0]).shape)
T_Two_Week_Comp_Amazon_Normalizer = np.empty(np.squeeze(T_Two_Week_Comp_Amazon_Unscaled[:,:,0]).shape)
T_Two_Week_Comp_Ocean_Normalizer = np.empty(np.squeeze(T_Two_Week_Comp_Ocean_Unscaled[:,:,0]).shape)
T_Diurnal_Avg_Amazon_Normalizer = np.empty(np.squeeze(T_Diurnal_Avg_Amazon_Unscaled[:,:,0]).shape)
T_Diurnal_Avg_Ocean_Normalizer = np.empty(np.squeeze(T_Diurnal_Avg_Ocean_Unscaled[:,:,0]).shape)
T_Diurnal_Int_Amazon_Normalizer = np.empty(np.squeeze(T_Diurnal_Int_Amazon_Unscaled[:,:,0]).shape)
T_Diurnal_Int_Ocean_Normalizer = np.empty(np.squeeze(T_Diurnal_Int_Ocean_Unscaled[:,:,0]).shape)

Q_Diurnal_Comp_Amazon_Normalizer = np.empty(np.squeeze(Q_Diurnal_Comp_Amazon_Unscaled[:,:,0]).shape)
Q_Diurnal_Comp_Ocean_Normalizer = np.empty(np.squeeze(Q_Diurnal_Comp_Ocean_Unscaled[:,:,0]).shape)
Q_Synoptic_Comp_Amazon_Normalizer = np.empty(np.squeeze(Q_Synoptic_Comp_Amazon_Unscaled[:,:,0]).shape)
Q_Synoptic_Comp_Ocean_Normalizer = np.empty(np.squeeze(Q_Synoptic_Comp_Ocean_Unscaled[:,:,0]).shape)
Q_Two_Week_Comp_Amazon_Normalizer = np.empty(np.squeeze(Q_Two_Week_Comp_Amazon_Unscaled[:,:,0]).shape)
Q_Two_Week_Comp_Ocean_Normalizer = np.empty(np.squeeze(Q_Two_Week_Comp_Ocean_Unscaled[:,:,0]).shape)
Q_Diurnal_Avg_Amazon_Normalizer = np.empty(np.squeeze(Q_Diurnal_Avg_Amazon_Unscaled[:,:,0]).shape)
Q_Diurnal_Avg_Ocean_Normalizer = np.empty(np.squeeze(Q_Diurnal_Avg_Ocean_Unscaled[:,:,0]).shape)
Q_Diurnal_Int_Amazon_Normalizer = np.empty(np.squeeze(Q_Diurnal_Int_Amazon_Unscaled[:,:,0]).shape)
Q_Diurnal_Int_Ocean_Normalizer = np.empty(np.squeeze(Q_Diurnal_Int_Ocean_Unscaled[:,:,0]).shape)

E_Diurnal_Comp_Amazon_Normalizer = np.empty(np.squeeze(E_Diurnal_Comp_Amazon_Unscaled[:,:,0]).shape)
E_Diurnal_Comp_Ocean_Normalizer = np.empty(np.squeeze(E_Diurnal_Comp_Ocean_Unscaled[:,:,0]).shape)
E_Synoptic_Comp_Amazon_Normalizer = np.empty(np.squeeze(E_Synoptic_Comp_Amazon_Unscaled[:,:,0]).shape)
E_Synoptic_Comp_Ocean_Normalizer = np.empty(np.squeeze(E_Synoptic_Comp_Ocean_Unscaled[:,:,0]).shape)
E_Two_Week_Comp_Amazon_Normalizer = np.empty(np.squeeze(E_Two_Week_Comp_Amazon_Unscaled[:,:,0]).shape)
E_Two_Week_Comp_Ocean_Normalizer = np.empty(np.squeeze(E_Two_Week_Comp_Ocean_Unscaled[:,:,0]).shape)
E_Diurnal_Avg_Amazon_Normalizer = np.empty(np.squeeze(E_Diurnal_Avg_Amazon_Unscaled[:,:,0]).shape)
E_Diurnal_Avg_Ocean_Normalizer = np.empty(np.squeeze(E_Diurnal_Avg_Ocean_Unscaled[:,:,0]).shape)
E_Diurnal_Int_Amazon_Normalizer = np.empty(np.squeeze(E_Diurnal_Int_Amazon_Unscaled[:,:,0]).shape)
E_Diurnal_Int_Ocean_Normalizer = np.empty(np.squeeze(E_Diurnal_Int_Ocean_Unscaled[:,:,0]).shape)

# %%
for i in range(len(T_Diurnal_Comp_Amazon_Unscaled)):
    for j in range(len(T_Diurnal_Comp_Amazon_Unscaled[0])):
        T_Diurnal_Comp_Amazon_Anon[i,j,:] = T_Diurnal_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(T_Diurnal_Comp_Amazon_Unscaled[i,j,:]) 
        T_Diurnal_Comp_Amazon_Normalizer[i,j] = np.nanmean(T_Diurnal_Comp_Amazon_Unscaled[i,j,:])
        T_Diurnal_Comp_Ocean_Anon[i,j,:] = T_Diurnal_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(T_Diurnal_Comp_Ocean_Unscaled[i,j,:]) 
        T_Diurnal_Comp_Ocean_Normalizer[i,j] = np.nanmean(T_Diurnal_Comp_Ocean_Unscaled[i,j,:])
        Q_Diurnal_Comp_Amazon_Anon[i,j,:] = Q_Diurnal_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(Q_Diurnal_Comp_Amazon_Unscaled[i,j,:]) 
        Q_Diurnal_Comp_Amazon_Normalizer[i,j] = np.nanmean(Q_Diurnal_Comp_Amazon_Unscaled[i,j,:])
        Q_Diurnal_Comp_Ocean_Anon[i,j,:] = Q_Diurnal_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(Q_Diurnal_Comp_Ocean_Unscaled[i,j,:]) 
        Q_Diurnal_Comp_Ocean_Normalizer[i,j] = np.nanmean(Q_Diurnal_Comp_Ocean_Unscaled[i,j,:])
        E_Diurnal_Comp_Amazon_Anon[i,j,:] = E_Diurnal_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(E_Diurnal_Comp_Amazon_Unscaled[i,j,:]) 
        E_Diurnal_Comp_Amazon_Normalizer[i,j] = np.nanmean(E_Diurnal_Comp_Amazon_Unscaled[i,j,:])
        E_Diurnal_Comp_Ocean_Anon[i,j,:] = E_Diurnal_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(E_Diurnal_Comp_Ocean_Unscaled[i,j,:]) 
        E_Diurnal_Comp_Ocean_Normalizer[i,j] = np.nanmean(E_Diurnal_Comp_Ocean_Unscaled[i,j,:])

# %%
for i in range(len(T_Synoptic_Comp_Amazon_Unscaled)):
    for j in range(len(T_Synoptic_Comp_Amazon_Unscaled[0])):
        T_Synoptic_Comp_Amazon_Anon[i,j,:] = T_Synoptic_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(T_Synoptic_Comp_Amazon_Unscaled[i,j,:]) 
        T_Synoptic_Comp_Amazon_Normalizer[i,j] = np.nanmean(T_Synoptic_Comp_Amazon_Unscaled[i,j,:])
        T_Synoptic_Comp_Ocean_Anon[i,j,:] = T_Synoptic_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(T_Synoptic_Comp_Ocean_Unscaled[i,j,:]) 
        T_Synoptic_Comp_Ocean_Normalizer[i,j] = np.nanmean(T_Synoptic_Comp_Ocean_Unscaled[i,j,:])
        Q_Synoptic_Comp_Amazon_Anon[i,j,:] = Q_Synoptic_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(Q_Synoptic_Comp_Amazon_Unscaled[i,j,:]) 
        Q_Synoptic_Comp_Amazon_Normalizer[i,j] = np.nanmean(Q_Synoptic_Comp_Amazon_Unscaled[i,j,:])
        Q_Synoptic_Comp_Ocean_Anon[i,j,:] = Q_Synoptic_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(Q_Synoptic_Comp_Ocean_Unscaled[i,j,:]) 
        Q_Synoptic_Comp_Ocean_Normalizer[i,j] = np.nanmean(Q_Synoptic_Comp_Ocean_Unscaled[i,j,:])
        E_Synoptic_Comp_Amazon_Anon[i,j,:] = E_Synoptic_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(E_Synoptic_Comp_Amazon_Unscaled[i,j,:]) 
        E_Synoptic_Comp_Amazon_Normalizer[i,j] = np.nanmean(E_Synoptic_Comp_Amazon_Unscaled[i,j,:])
        E_Synoptic_Comp_Ocean_Anon[i,j,:] = E_Synoptic_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(E_Synoptic_Comp_Ocean_Unscaled[i,j,:]) 
        E_Synoptic_Comp_Ocean_Normalizer[i,j] = np.nanmean(E_Synoptic_Comp_Ocean_Unscaled[i,j,:])

# %%
for i in range(len(T_Two_Week_Comp_Amazon_Unscaled)):
    for j in range(len(T_Two_Week_Comp_Amazon_Unscaled[0])):
        T_Two_Week_Comp_Amazon_Anon[i,j,:] = T_Two_Week_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(T_Two_Week_Comp_Amazon_Unscaled[i,j,:]) 
        T_Two_Week_Comp_Amazon_Normalizer[i,j] = np.nanmean(T_Two_Week_Comp_Amazon_Unscaled[i,j,:])
        T_Two_Week_Comp_Ocean_Anon[i,j,:] = T_Two_Week_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(T_Two_Week_Comp_Ocean_Unscaled[i,j,:]) 
        T_Two_Week_Comp_Ocean_Normalizer[i,j] = np.nanmean(T_Two_Week_Comp_Ocean_Unscaled[i,j,:])
        Q_Two_Week_Comp_Amazon_Anon[i,j,:] = Q_Two_Week_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(Q_Two_Week_Comp_Amazon_Unscaled[i,j,:]) 
        Q_Two_Week_Comp_Amazon_Normalizer[i,j] = np.nanmean(Q_Two_Week_Comp_Amazon_Unscaled[i,j,:])
        Q_Two_Week_Comp_Ocean_Anon[i,j,:] = Q_Two_Week_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(Q_Two_Week_Comp_Ocean_Unscaled[i,j,:]) 
        Q_Two_Week_Comp_Ocean_Normalizer[i,j] = np.nanmean(Q_Two_Week_Comp_Ocean_Unscaled[i,j,:])
        E_Two_Week_Comp_Amazon_Anon[i,j,:] = E_Two_Week_Comp_Amazon_Unscaled[i,j,:] - np.nanmean(E_Two_Week_Comp_Amazon_Unscaled[i,j,:]) 
        E_Two_Week_Comp_Amazon_Normalizer[i,j] = np.nanmean(E_Two_Week_Comp_Amazon_Unscaled[i,j,:])
        E_Two_Week_Comp_Ocean_Anon[i,j,:] = E_Two_Week_Comp_Ocean_Unscaled[i,j,:] - np.nanmean(E_Two_Week_Comp_Ocean_Unscaled[i,j,:]) 
        E_Two_Week_Comp_Ocean_Normalizer[i,j] = np.nanmean(E_Two_Week_Comp_Ocean_Unscaled[i,j,:])

# %%
for i in range(len(T_Diurnal_Avg_Amazon_Unscaled)):
    for j in range(len(T_Diurnal_Avg_Amazon_Unscaled[0])):
        T_Diurnal_Avg_Amazon_Anon[i,j,:] = T_Diurnal_Avg_Amazon_Unscaled[i,j,:] - np.nanmean(T_Diurnal_Avg_Amazon_Unscaled[i,j,:]) 
        T_Diurnal_Avg_Amazon_Normalizer[i,j] = np.nanmean(T_Diurnal_Avg_Amazon_Unscaled[i,j,:])
        T_Diurnal_Avg_Ocean_Anon[i,j,:] = T_Diurnal_Avg_Ocean_Unscaled[i,j,:] - np.nanmean(T_Diurnal_Avg_Ocean_Unscaled[i,j,:]) 
        T_Diurnal_Avg_Ocean_Normalizer[i,j] = np.nanmean(T_Diurnal_Avg_Ocean_Unscaled[i,j,:])
        Q_Diurnal_Avg_Amazon_Anon[i,j,:] = Q_Diurnal_Avg_Amazon_Unscaled[i,j,:] - np.nanmean(Q_Diurnal_Avg_Amazon_Unscaled[i,j,:]) 
        Q_Diurnal_Avg_Amazon_Normalizer[i,j] = np.nanmean(Q_Diurnal_Avg_Amazon_Unscaled[i,j,:])
        Q_Diurnal_Avg_Ocean_Anon[i,j,:] = Q_Diurnal_Avg_Ocean_Unscaled[i,j,:] - np.nanmean(Q_Diurnal_Avg_Ocean_Unscaled[i,j,:]) 
        Q_Diurnal_Avg_Ocean_Normalizer[i,j] = np.nanmean(Q_Diurnal_Avg_Ocean_Unscaled[i,j,:])
        E_Diurnal_Avg_Amazon_Anon[i,j,:] = E_Diurnal_Avg_Amazon_Unscaled[i,j,:] - np.nanmean(E_Diurnal_Avg_Amazon_Unscaled[i,j,:]) 
        E_Diurnal_Avg_Amazon_Normalizer[i,j] = np.nanmean(E_Diurnal_Avg_Amazon_Unscaled[i,j,:])
        E_Diurnal_Avg_Ocean_Anon[i,j,:] = E_Diurnal_Avg_Ocean_Unscaled[i,j,:] - np.nanmean(E_Diurnal_Avg_Ocean_Unscaled[i,j,:]) 
        E_Diurnal_Avg_Ocean_Normalizer[i,j] = np.nanmean(E_Diurnal_Avg_Ocean_Unscaled[i,j,:])

# %%
for i in range(len(T_Diurnal_Int_Amazon_Unscaled)):
    for j in range(len(T_Diurnal_Int_Amazon_Unscaled[0])):
        T_Diurnal_Int_Amazon_Anon[i,j,:] = T_Diurnal_Int_Amazon_Unscaled[i,j,:] - np.nanmean(T_Diurnal_Int_Amazon_Unscaled[i,j,:]) 
        T_Diurnal_Int_Amazon_Normalizer[i,j] = np.nanmean(T_Diurnal_Int_Amazon_Unscaled[i,j,:])
        T_Diurnal_Int_Ocean_Anon[i,j,:] = T_Diurnal_Int_Ocean_Unscaled[i,j,:] - np.nanmean(T_Diurnal_Int_Ocean_Unscaled[i,j,:]) 
        T_Diurnal_Int_Ocean_Normalizer[i,j] = np.nanmean(T_Diurnal_Int_Ocean_Unscaled[i,j,:])
        Q_Diurnal_Int_Amazon_Anon[i,j,:] = Q_Diurnal_Int_Amazon_Unscaled[i,j,:] - np.nanmean(Q_Diurnal_Int_Amazon_Unscaled[i,j,:]) 
        Q_Diurnal_Int_Amazon_Normalizer[i,j] = np.nanmean(Q_Diurnal_Int_Amazon_Unscaled[i,j,:])
        Q_Diurnal_Int_Ocean_Anon[i,j,:] = Q_Diurnal_Int_Ocean_Unscaled[i,j,:] - np.nanmean(Q_Diurnal_Int_Ocean_Unscaled[i,j,:]) 
        Q_Diurnal_Int_Ocean_Normalizer[i,j] = np.nanmean(Q_Diurnal_Int_Ocean_Unscaled[i,j,:])
        E_Diurnal_Int_Amazon_Anon[i,j,:] = E_Diurnal_Int_Amazon_Unscaled[i,j,:] - np.nanmean(E_Diurnal_Int_Amazon_Unscaled[i,j,:]) 
        E_Diurnal_Int_Amazon_Normalizer[i,j] = np.nanmean(E_Diurnal_Int_Amazon_Unscaled[i,j,:])
        E_Diurnal_Int_Ocean_Anon[i,j,:] = E_Diurnal_Int_Ocean_Unscaled[i,j,:] - np.nanmean(E_Diurnal_Int_Ocean_Unscaled[i,j,:]) 
        E_Diurnal_Int_Ocean_Normalizer[i,j] = np.nanmean(E_Diurnal_Int_Ocean_Unscaled[i,j,:])

# %%
Anon_T_Max = np.load("/fast/gmooers/Preprocessed_Data/T_Variable/Space_Time_Anon_Max_Scalar.npy")
Anon_T_Min = np.load("/fast/gmooers/Preprocessed_Data/T_Variable/Space_Time_Anon_Min_Scalar.npy")
Anon_Q_Max = np.load("/fast/gmooers/Preprocessed_Data/Q_Variable/Space_Time_Anon_Max_Scalar.npy")
Anon_Q_Min = np.load("/fast/gmooers/Preprocessed_Data/Q_Variable/Space_Time_Anon_Min_Scalar.npy")
Anon_E_Max = np.load("/fast/gmooers/Preprocessed_Data/Enthalpy_Variable/Space_Time_Anon_Max_Scalar.npy")
Anon_E_Min = np.load("/fast/gmooers/Preprocessed_Data/Enthalpy_Variable/Space_Time_Anon_Min_Scalar.npy")

# %%
T_Diurnal_Comp_Amazon_Rescaled = np.interp(T_Diurnal_Comp_Amazon_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Diurnal_Comp_Ocean_Rescaled = np.interp(T_Diurnal_Comp_Ocean_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Synoptic_Comp_Amazon_Rescaled = np.interp(T_Synoptic_Comp_Amazon_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Synoptic_Comp_Ocean_Rescaled = np.interp(T_Synoptic_Comp_Ocean_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Two_Week_Comp_Amazon_Rescaled = np.interp(T_Two_Week_Comp_Amazon_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Two_Week_Comp_Ocean_Rescaled = np.interp(T_Two_Week_Comp_Ocean_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Diurnal_Avg_Amazon_Rescaled = np.interp(T_Diurnal_Avg_Amazon_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Diurnal_Avg_Ocean_Rescaled = np.interp(T_Diurnal_Avg_Ocean_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Diurnal_Int_Amazon_Rescaled = np.interp(T_Diurnal_Int_Amazon_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))
T_Diurnal_Int_Ocean_Rescaled = np.interp(T_Diurnal_Int_Ocean_Anon, (Anon_T_Min, Anon_T_Max), (0, 1))

Q_Diurnal_Comp_Amazon_Rescaled = np.interp(Q_Diurnal_Comp_Amazon_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Diurnal_Comp_Ocean_Rescaled = np.interp(Q_Diurnal_Comp_Ocean_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Synoptic_Comp_Amazon_Rescaled = np.interp(Q_Synoptic_Comp_Amazon_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Synoptic_Comp_Ocean_Rescaled = np.interp(Q_Synoptic_Comp_Ocean_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Two_Week_Comp_Amazon_Rescaled = np.interp(Q_Two_Week_Comp_Amazon_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Two_Week_Comp_Ocean_Rescaled = np.interp(Q_Two_Week_Comp_Ocean_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Diurnal_Avg_Amazon_Rescaled = np.interp(Q_Diurnal_Avg_Amazon_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Diurnal_Avg_Ocean_Rescaled = np.interp(Q_Diurnal_Avg_Ocean_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Diurnal_Int_Amazon_Rescaled = np.interp(Q_Diurnal_Int_Amazon_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))
Q_Diurnal_Int_Ocean_Rescaled = np.interp(Q_Diurnal_Int_Ocean_Anon, (Anon_Q_Min, Anon_Q_Max), (0, 1))

E_Diurnal_Comp_Amazon_Rescaled = np.interp(E_Diurnal_Comp_Amazon_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Diurnal_Comp_Ocean_Rescaled = np.interp(E_Diurnal_Comp_Ocean_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Synoptic_Comp_Amazon_Rescaled = np.interp(E_Synoptic_Comp_Amazon_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Synoptic_Comp_Ocean_Rescaled = np.interp(E_Synoptic_Comp_Ocean_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Two_Week_Comp_Amazon_Rescaled = np.interp(E_Two_Week_Comp_Amazon_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Two_Week_Comp_Ocean_Rescaled = np.interp(E_Two_Week_Comp_Ocean_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Diurnal_Avg_Amazon_Rescaled = np.interp(E_Diurnal_Avg_Amazon_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Diurnal_Avg_Ocean_Rescaled = np.interp(E_Diurnal_Avg_Ocean_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Diurnal_Int_Amazon_Rescaled = np.interp(E_Diurnal_Int_Amazon_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))
E_Diurnal_Int_Ocean_Rescaled = np.interp(E_Diurnal_Int_Ocean_Anon, (Anon_E_Min, Anon_E_Max), (0, 1))

# %%
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/T_amazon_point.npy", T_Diurnal_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/T_ocean_point.npy", T_Diurnal_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/T_amazon_point.npy", T_Synoptic_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/T_ocean_point.npy", T_Synoptic_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/T_amazon_point.npy", T_Two_Week_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/T_ocean_point.npy", T_Two_Week_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/T_amazon_region.npy", T_Diurnal_Avg_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/T_ocean_region.npy", T_Diurnal_Avg_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/T_amazon_region.npy", T_Diurnal_Int_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/T_ocean_region.npy", T_Diurnal_Int_Ocean_Rescaled)

np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/Q_amazon_point.npy", Q_Diurnal_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/Q_ocean_point.npy", Q_Diurnal_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/Q_amazon_point.npy", Q_Synoptic_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/Q_ocean_point.npy", Q_Synoptic_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/Q_amazon_point.npy", Q_Two_Week_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/Q_ocean_point.npy", Q_Two_Week_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/Q_amazon_region.npy", Q_Diurnal_Avg_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/Q_ocean_region.npy", Q_Diurnal_Avg_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/Q_amazon_region.npy", Q_Diurnal_Int_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/Q_ocean_region.npy", Q_Diurnal_Int_Ocean_Rescaled)

np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/E_amazon_point.npy", E_Diurnal_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/E_ocean_point.npy", E_Diurnal_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/E_amazon_point.npy", E_Synoptic_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/E_ocean_point.npy", E_Synoptic_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/E_amazon_point.npy", E_Two_Week_Comp_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/E_ocean_point.npy", E_Two_Week_Comp_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/E_amazon_region.npy", E_Diurnal_Avg_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/E_ocean_region.npy", E_Diurnal_Avg_Ocean_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/E_amazon_region.npy", E_Diurnal_Int_Amazon_Rescaled)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/E_ocean_region.npy", E_Diurnal_Int_Ocean_Rescaled)

# %%
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/T_amazon_Normalizer.npy", T_Diurnal_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/T_ocean_Normalizer.npy", T_Diurnal_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/T_amazon_Normalizer.npy", T_Synoptic_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/T_ocean_Normalizer.npy", T_Synoptic_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/T_amazon_Normalizer.npy", T_Two_Week_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/T_ocean_Normalizer.npy", T_Two_Week_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/T_amazon_Normalizer.npy", T_Diurnal_Avg_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/T_ocean_Normalizer.npy", T_Diurnal_Avg_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/T_amazon_Normalizer.npy", T_Diurnal_Int_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/T_ocean_Normalizer.npy", T_Diurnal_Int_Ocean_Normalizer)

np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/Q_amazon_Normalizer.npy", Q_Diurnal_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/Q_ocean_Normalizer.npy", Q_Diurnal_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/Q_amazon_Normalizer.npy", Q_Synoptic_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/Q_ocean_Normalizer.npy", Q_Synoptic_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/Q_amazon_Normalizer.npy", Q_Two_Week_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/Q_ocean_Normalizer.npy", Q_Two_Week_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/Q_amazon_Normalizer.npy", Q_Diurnal_Avg_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/Q_ocean_Normalizer.npy", Q_Diurnal_Avg_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/Q_amazon_Normalizer.npy", Q_Diurnal_Int_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/Q_ocean_Normalizer.npy", Q_Diurnal_Int_Ocean_Normalizer)

np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/E_amazon_Normalizer.npy", E_Diurnal_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Composite/E_ocean_Normalizer.npy", E_Diurnal_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/E_amazon_Normalizer.npy", E_Synoptic_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Synoptic_Composite/E_ocean_Normalizer.npy", E_Synoptic_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/E_amazon_Normalizer.npy", E_Two_Week_Comp_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/2_Week_Composite/E_ocean_Normalizer.npy", E_Two_Week_Comp_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/E_amazon_Normalizer.npy", E_Diurnal_Avg_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Avg/E_ocean_Normalizer.npy", E_Diurnal_Avg_Ocean_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/E_amazon_Normalizer.npy", E_Diurnal_Int_Amazon_Normalizer)
np.save("/fast/gmooers/Preprocessed_Data/Fixed_Anon_Synoptic_test_Data/Diurnal_Interval/E_ocean_Normalizer.npy", E_Diurnal_Int_Ocean_Normalizer)
